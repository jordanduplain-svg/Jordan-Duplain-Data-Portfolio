# %% [markdown]
# Corrélation Syndrome Cognitifs et Age

# %%
import pandas as pd

df=pd.read_csv('C:\\Users\\jorda\\PycharmProjects\\Aicha_These\\data\\Thesis_Aicha_Data_Basic.csv',sep=';')
df
#Corrélation pas possible pour le délai, pas de colonnes
# Out:
#      Sexe                                   Mode_entree_note  Mode_entree  \
# 0       1                 Troubles mnésiques, désorientation          1.0
# 1       2               Cognitif (2010) : troubles mnésiques          1.0
# 2       2            Cognitif (2013) : troubles dyséxécutifs          1.0
# 3       2  Cognitif (2012) : troubles du langage et de la...          1.0
# 4       1  Psychiatrique (2016) : troubles du comportemen...          2.0
# ..    ...                                                ...          ...
# 105     2                                  Plainte cognitive          1.0
# 106     2                                  Plainte cognitive          1.0
# 107     2                                  Plainte cognitive          1.0
# 108     2                                                NaN          NaN
# 109     2                                                NaN          NaN
#
#      Age_debut_symptomes  Symptomes_prodromaux TCSP_prodr  \
# ...

# %%
df2=df[['Age_debut_symptomes','Date_symptomes_cognitifs']]
df2
# Out:
#      Age_debut_symptomes Date_symptomes_cognitifs
# 0                   78.0                        0
# 1                   63.0                        0
# 2                   58.0                        0
# 3                   52.0                        0
# 4                   71.0                        1
# ..                   ...                      ...
# 105                 76.0                        0
# 106                 48.0                      NaN
# 107                 52.0                        0
# 108                  NaN                      NaN
# 109                  NaN                      NaN
#
# [110 rows x 2 columns]

# %%
df2=df2.dropna()

# %%
df2['Date_symptomes_cognitifs'].unique()
# Out:
# array(['0', '1', '0,5', '2', '16', '3', '4'], dtype=object)

# %%
df2['Date_symptomes_cognitifs'] = (
    df2['Date_symptomes_cognitifs']
    .str.replace(',', '.', regex=False)
    .astype(float)
)
# Out:
# C:\Users\jorda\AppData\Local\Temp\ipykernel_29108\3420241050.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Date_symptomes_cognitifs'] = (

# %%
df2['Date_symptomes_cognitifs'].unique()
# Out:
# array([ 0. ,  1. ,  0.5,  2. , 16. ,  3. ,  4. ])

# %%
df2['Age_debut_symptomes'].corr(df2['Date_symptomes_cognitifs'])
# Out:
# np.float64(-0.181805438811796)

# %% [markdown]
# Corrélation négative faible, le délai des syndromes cognitifs tant a diminuer avec l'age
