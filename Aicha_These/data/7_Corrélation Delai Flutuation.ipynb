# %% [markdown]
# Corrélation Fultuation et Age

# %%
import pandas as pd

df=pd.read_csv('C:\\Users\\jorda\\PycharmProjects\\Aicha_These\\data\\Thesis_Aicha_Data_Basic.csv',sep=';')
df
# Out:
#      Sexe                                   Mode_entree_note  Mode_entree  \
# 0       1                 Troubles mnésiques, désorientation          1.0
# 1       2               Cognitif (2010) : troubles mnésiques          1.0
# 2       2            Cognitif (2013) : troubles dyséxécutifs          1.0
# 3       2  Cognitif (2012) : troubles du langage et de la...          1.0
# 4       1  Psychiatrique (2016) : troubles du comportemen...          2.0
# ..    ...                                                ...          ...
# 105     2                                  Plainte cognitive          1.0
# 106     2                                  Plainte cognitive          1.0
# 107     2                                  Plainte cognitive          1.0
# 108     2                                                NaN          NaN
# 109     2                                                NaN          NaN
#
#      Age_debut_symptomes  Symptomes_prodromaux TCSP_prodr  \
# ...

# %%
df2=df[['Age_debut_symptomes','Delai_fluctuations']]
df2
# Out:
#      Age_debut_symptomes  Delai_fluctuations
# 0                   78.0                 0.0
# 1                   63.0                 7.0
# 2                   58.0                 3.0
# 3                   52.0                 1.0
# 4                   71.0                 NaN
# ..                   ...                 ...
# 105                 76.0                 NaN
# 106                 48.0                 NaN
# 107                 52.0                 3.0
# 108                  NaN                 NaN
# 109                  NaN                 NaN
#
# [110 rows x 2 columns]

# %%
df2=df2.dropna()

# %%
df2['Delai_fluctuations'].unique()
# Out:
# array([ 0.,  7.,  3.,  1.,  6.,  8.,  5.,  4., 10.,  2., 12., 18., 15.])

# %%
df2
# Out:
#      Age_debut_symptomes  Delai_fluctuations
# 0                   78.0                 0.0
# 1                   63.0                 7.0
# 2                   58.0                 3.0
# 3                   52.0                 1.0
# 5                   67.0                 6.0
# 6                   66.0                 8.0
# 7                   66.0                 5.0
# 10                  74.0                 4.0
# 11                  66.0                 0.0
# 15                  59.0                10.0
# 16                  65.0                 3.0
# 17                  75.0                 0.0
# 18                  67.0                 2.0
# 19                  67.0                 1.0
# 20                  64.0                 1.0
# 21                  65.0                 2.0
# 22                  53.0                 4.0
# 23                  78.0                 4.0
# 24                  72.0                 4.0
# 25                  49.0                12.0
# ...

# %%
df2['Age_debut_symptomes'].corr(df2['Delai_fluctuations'])
# Out:
# np.float64(-0.42771370372925316)

# %% [markdown]
# Corrélation négative moyenne, Le délai est légérement plus long chez les jeunes que les vieux
