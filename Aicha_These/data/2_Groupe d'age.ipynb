# %% [markdown]
# Création de groupe d'age :
# < 65 ans
# 65 à 75 ans
# Plus de 75 ans

# %%
import pandas as pd
import numpy as np

df=pd.read_csv('C:\\Users\\jorda\\PycharmProjects\\Aicha_These\\data\\Thesis_Aicha_Data V2.csv', sep=";")

# %%
bins=[0,65,75,100]
labels=['0-65','66-75','77-100']
df["Tranche_age"] = pd.cut(df['Age_debut_symptomes'], bins=bins,labels=labels,right=True)

# %%
df["Tranche_age"] = pd.cut(df['Age_debut_symptomes'], bins=bins,labels=labels,right=True)

# %%
df.to_csv('Thesis_Aicha_Data V3.csv', encoding='utf-8', sep=';',index=False)
