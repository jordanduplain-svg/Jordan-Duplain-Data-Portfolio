# %% [markdown]
# Corrélation Syndrome Extrapyramidal et Age

# %%
import pandas as pd

df=pd.read_csv('C:\\Users\\jorda\\PycharmProjects\\Aicha_These\\data\\Thesis_Aicha_Data_Basic.csv',sep=';')
df
# Out:
#      Sexe                                   Mode_entree_note  Mode_entree  \
# 0       1                 Troubles mnésiques, désorientation          1.0
# 1       2               Cognitif (2010) : troubles mnésiques          1.0
# 2       2            Cognitif (2013) : troubles dyséxécutifs          1.0
# 3       2  Cognitif (2012) : troubles du langage et de la...          1.0
# 4       1  Psychiatrique (2016) : troubles du comportemen...          2.0
# ..    ...                                                ...          ...
# 105     2                                  Plainte cognitive          1.0
# 106     2                                  Plainte cognitive          1.0
# 107     2                                  Plainte cognitive          1.0
# 108     2                                                NaN          NaN
# 109     2                                                NaN          NaN
#
#      Age_debut_symptomes  Symptomes_prodromaux TCSP_prodr  \
# ...

# %%
df2=df[['Age_debut_symptomes','Delai_syndrome_extrapyramidal']]
df2
# Out:
#      Age_debut_symptomes Delai_syndrome_extrapyramidal
# 0                   78.0                           0,5
# 1                   63.0                           NaN
# 2                   58.0                             4
# 3                   52.0                             0
# 4                   71.0                           NaN
# ..                   ...                           ...
# 105                 76.0                           NaN
# 106                 48.0                           NaN
# 107                 52.0                             3
# 108                  NaN                           NaN
# 109                  NaN                           NaN
#
# [110 rows x 2 columns]

# %%
df2=df2.dropna()

# %%
df2['Delai_syndrome_extrapyramidal'].unique()
# Out:
# array(['0,5', '4', '0', '6', '3', '2', '9', '1,5', '1', '5', '19', '15',
#        '8', '7'], dtype=object)

# %%
df2['Delai_syndrome_extrapyramidal'] = (
    df2['Delai_syndrome_extrapyramidal']
    .str.replace(',', '.', regex=False)
    .astype(float)
)
# Out:
# C:\Users\jorda\AppData\Local\Temp\ipykernel_27536\791398486.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Delai_syndrome_extrapyramidal'] = (

# %%
df2['Delai_syndrome_extrapyramidal'].astype(float)
# Out:
# 0       0.5
# 2       4.0
# 3       0.0
# 5       4.0
# 6       4.0
# 7       6.0
# 9       0.5
# 10      4.0
# 11      3.0
# 13      4.0
# 14      2.0
# 15      9.0
# 16      1.5
# 19      1.0
# 21      0.0
# 22      5.0
# 23      0.0
# 29      0.0
# 30      1.0
# 34     19.0
# 35     15.0
# 36      3.0
# 38      8.0
# 39      2.0
# 40      0.0
# 41      6.0
# 42      3.0
# 43      0.0
# 45      6.0
# 46      4.0
# 50      2.0
# 52      6.0
# 53      4.0
# 55      0.0
# 56      2.0
# 57      0.0
# 58      0.0
# 62      5.0
# 68      2.0
# 69      2.0
# 71      5.0
# 74      2.0
# 75      2.0
# 76      3.0
# 77      4.0
# 78      2.0
# 81      2.0
# 82      4.0
# 84      7.0
# 85      1.0
# 87      0.0
# 89      3.0
# 91      7.0
# 93      0.0
# 98      2.0
# 100     4.0
# 103     0.0
# 104     3.0
# 107     3.0
# Name: Delai_syndrome_extrapyramidal, dtype: float64

# %%
df2['Delai_syndrome_extrapyramidal'].unique()
# Out:
# array([ 0.5,  4. ,  0. ,  6. ,  3. ,  2. ,  9. ,  1.5,  1. ,  5. , 19. ,
#        15. ,  8. ,  7. ])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 59 entries, 0 to 107
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age_debut_symptomes            59 non-null     float64
#  1   Delai_syndrome_extrapyramidal  59 non-null     float64
# dtypes: float64(2)
# memory usage: 1.4 KB

# %%
df2['Age_debut_symptomes'].corr(df2['Delai_syndrome_extrapyramidal'])
# Out:
# np.float64(-0.33189233950524755)

# %% [markdown]
# Corrélation faible négative, Cela tenda a montrer que les jeunes ont un délai du syndrome plus long que les personnes + vielle
